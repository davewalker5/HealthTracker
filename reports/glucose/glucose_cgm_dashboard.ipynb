# %%
from datetime import date, timedelta, datetime

# Reporting date range start dates
start_dates = [
    date(2025, 4, 17),
    date(2025, 5, 9),
    date(2025, 6, 27),
    date(2025, 8, 4),
    date(2025, 12, 1),
    date(2025, 12, 22)
]

# Exclusion date ranges - this should be a list of tuples in which each tuple has two
# members, a start date and time and end date and time in that order
exclusions = [
    (datetime(2025, 8, 6, 6, 52, 0), datetime(2025, 8, 6, 23, 59, 59)),
    (datetime(2025, 8, 12, 15, 7, 0), datetime(2025, 8, 12, 16, 52, 59)),
    (datetime(2025, 12, 25, 0, 0, 0), datetime(2025, 12, 26, 23, 59, 59))
]

# Whether to export the data
export_spreadsheet = True
export_html_dashboard = True

# %%
# %run ../api.ipynb
# %run ../config.ipynb
# %run ../export.ipynb

# %%
MEAN_GLUCOSE_THRESHOLD = 7.0
CV_THRESHOLD = 0.36
STABILITY_THRESHOLD = 3.0
RMSSD_REFERENCE = 0.05
CHART_EXPORT_FORMAT = "png"

# %% [markdown]
# ## CGM Stability Metrics Calculation from Raw Data
#
# Metrics defined by the International CGM Consensus (ATTD / ADA) are indicated using a (*) in the following table:
#
# | Metric | Measures              | Captures              | Type                               |
# | ------ | --------------------- | --------------------- | ---------------------------------- |
# | Mean   | Central level         | Overall glycaemia     | Standard (*)                       |
# | CV     | Dispersion            | Variability amplitude | Recommended variability metric (*) |
# | RMSSD  | Short-term volatility | Spikes / rapid swings | Exploratory variability analysis   |
# | TV     | Total movement        | Oscillatory behaviour | Exploratory variability analysis   |
# | TIR    | Target adherence      | Clinical control      | Core clinical metric (*)           |
#
# Example patterns:
#
# | Pattern                   | Mean | CV       | RMSSD    | TV       | TIR      |
# | ------------------------- | ---- | -------- | -------- | -------- | -------- |
# | Flat healthy profile      | good | low      | low      | low      | high     |
# | Meal spikes               | ok   | moderate | high     | moderate | moderate |
# | Oscillating control       | ok   | high     | moderate | high     | moderate |
# | Persistent hyperglycaemia | high | low      | low      | low      | low      |

# %%
def cgm_stability_metrics(df):
    g = df["level"]
    mean = g.mean()
    return {
        "sensor_id": min(df["date"]).strftime("%y%m%d"),
        "start": min(df["date"]),
        "end": max(df["date"]),
        "mean": mean,
        "cv": g.std() / mean,
        "rmssd_normalised": (g.diff()**2).mean()**0.5 / mean,
        "tv_normalised": g.diff().abs().sum() / (len(g) * mean),
        "tir": ((g >= 3.9) & (g <= 10.0)).mean()
    }

# %% [markdown]
# ## Stability Index
#
# Instability is defined as the sum of three dimensionless CGM variability components - coefficient of variation, normalised RMSSD, and normalised total variation. In practice, the result is a CV-dominated instability metric that penalises additional short-term spikes and oscillatory glucose movement.
#
# Stability is defined as the inverse of this composite variability such that:
#
# - Lower instability = smoother glucose dynamics
# - Higher stability index = better overall glucose stability
#
# Note that the index is intended for within-user sensor-to-sensor comparison, not clinical benchmarking.

# %%
import numpy as np

def add_stability_index(metrics_df):
    df = metrics_df.copy()

    # Guardrails
    for col in ["cv", "rmssd_normalised", "tv_normalised"]:
        if col not in df.columns:
            df[col] = np.nan

    # Composite variability
    df["instability"] = df["cv"] + df["rmssd_normalised"] + df["tv_normalised"].replace([np.inf, -np.inf], np.nan)

    # Practical composite stability index (higher = better)
    df["stability_index"] = 1 / df["instability"]

    # Show columns indicating the contribution from each metric as a %
    df["cv_contribution"] = 100.0 * df["cv"] / df["instability"]
    df["rmssd_contribution"] = 100.0 * df["rmssd_normalised"] / df["instability"]
    df["tv_contribution"] = 100.0 * df["tv_normalised"] / df["instability"]

    return df

# %% [markdown]
# ## Load Per-Sensor Data and Calculate Stability Metrics

# %%
import pandas as pd

# Log in to the service, get the person ID and retrieve the data
token = authenticate(url, username, password)
person_id = get_person_id(url, token, firstnames, surname)

# Iterate over each date
measurements_list = []
metrics_list = []
for start_date in start_dates:
    # Calculate the end date based on sensor lifespan and load the data
    end_date = start_date + timedelta(days=11)
    df = get_glucose_measurements(url, token, person_id, start_date, end_date)

    # Remove any excluded ranges
    df = remove_records_for_date_ranges(df, exclusions)

    # Add this data set to the list
    measurements_list.append(df)

    # Calculate the metrics and append them to the metrics list
    stability_metrics = cgm_stability_metrics(df)
    metrics_list.append(stability_metrics)

# Conver the stability metrics list to a data frame and preview the data
metrics_df = pd.DataFrame(metrics_list)
metrics_df = metrics_df.set_index("sensor_id")
metrics_df = add_stability_index(metrics_df)

# Ensure sensor_id is treated as a string for plotting
metrics_df.index = metrics_df.index.astype(str)
display(metrics_df)

# %% [markdown]
# ## Chart CV and Mean Glucose per Sensor

# %%
import matplotlib.pyplot as plt

x = range(len(metrics_df))

fig, ax1 = plt.subplots(figsize=(12,6))

# --- CV bar chart ---
ax1.bar(x, metrics_df["cv"], color="orangered")
ax1.set_xlabel("Sensor ID")
ax1.set_ylabel("Coefficient of Variation (CV)")
ax1.set_xticks(x)
ax1.set_xticklabels(metrics_df.index)

# --- Mean glucose line (secondary axis) ---
ax2 = ax1.twinx()
ax2.plot(x, metrics_df["mean"], marker="o", color="yellowgreen", linewidth=3)
ax2.set_ylabel("Mean Glucose (mmol/L)")

plt.title("Variability and Mean Glucose")
plt.tight_layout()

export_chart("glucose", "variabliity_and_mean_glucose", None, CHART_EXPORT_FORMAT)
plt.show()

# %%
import matplotlib.pyplot as plt

x = range(len(metrics_df))

fig, ax = plt.subplots(figsize=(12,6))

ax.bar(x, metrics_df["stability_index"], color="orangered")

ax.set_xlabel("Sensor ID")
ax.set_ylabel("Stability Index")
ax.set_title("Glucose Stability")

ax.set_xticks(x)
ax.set_xticklabels(metrics_df.index)

plt.tight_layout()

export_chart("glucose", "glucose_stability", None, CHART_EXPORT_FORMAT)
plt.show()

# %% [markdown]
# ## CV vs Mean Glucose
#
# The stability index is mathematically defined from accepted variability metrics, so plotting it against glucose level is reasonable.
#
# | Region              | Meaning                     |
# | ------------------- | --------------------------- |
# | low mean + low CV   | ideal control               |
# | high mean + low CV  | stable but elevated glucose |
# | low mean + high CV  | good average but unstable   |
# | high mean + high CV | poor control                |

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12,6))

ax.scatter(metrics_df["mean"], metrics_df["cv"])

# Label each sensor
for i, txt in enumerate(metrics_df.index):
    ax.annotate(txt, (metrics_df["mean"].iloc[i], metrics_df["cv"].iloc[i]))

# Quadrant reference lines
ax.axvline(MEAN_GLUCOSE_THRESHOLD, linestyle="--")
ax.axhline(CV_THRESHOLD, linestyle="--")

ax.set_xlabel("Mean Glucose (mmol/L)")
ax.set_ylabel("Coefficient of Variation (CV)")
ax.set_title("Glucose Level vs Variability")

plt.tight_layout()

export_chart("glucose", "glucose_level_vs_variability", None, CHART_EXPORT_FORMAT)
plt.show()

# %% [markdown]
# ## Stability vs Mean Glucose
#
# | Quadrant     | Interpretation                   |
# | ------------ | -------------------------------- |
# | top-left     | ideal: low glucose + stable      |
# | top-right    | stable but elevated glucose      |
# | bottom-left  | good average but unstable swings |
# | bottom-right | unstable and elevated            |

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12,6))

ax.scatter(metrics_df["mean"], metrics_df["stability_index"])

ax.axvline(MEAN_GLUCOSE_THRESHOLD, linestyle="--", linewidth=1, alpha=0.6)
ax.axhline(STABILITY_THRESHOLD, linestyle="--", linewidth=1, alpha=0.6)

# Label sensors
for i, txt in enumerate(metrics_df.index):
    ax.annotate(txt, (metrics_df["mean"].iloc[i], metrics_df["stability_index"].iloc[i]))

ax.set_xlabel("Mean Glucose (mmol/L)")
ax.set_ylabel("Stability Index")
ax.set_title("Glucose Level vs Stability")

plt.tight_layout()

export_chart("glucose", "glucose_level_vs_stability", None, CHART_EXPORT_FORMAT)
plt.show()

# %% [markdown]
# ## GLycaemic Variability Metrics

# %%
import matplotlib.pyplot as plt

metrics_df[["cv","rmssd_normalised","tv_normalised"]].plot(
    kind="bar",
    figsize=(12,6)
)

plt.ylabel("Variability Metric Value")
plt.title("Components of Glycaemic Variability")
plt.xticks(rotation=45)

export_chart("glucose", "glycaemic_variability_metrics", None, CHART_EXPORT_FORMAT)
plt.show()

# %%
# Export the data to a spreadsheet
if export_spreadsheet:
    export_to_spreadsheet("glucose", "glucose_cgm_dashboard", { "Sensor Metrics": metrics_df })
